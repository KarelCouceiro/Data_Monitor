# %% [markdown]
# <a href="https://colab.research.google.com/github/KarelCouceiro/Data_Monitor/blob/main/Code_llama_7B_Instruct_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests as req

# %%
headers = {'Authorization': 'Bearer NQSoZhqYnRRJIDuIL5upcQ5geKeM'}

# %%
url = "http://ops.epo.org/3.2/rest-services/register/search?q=ti%3Dai"

# %%
response = req.get(url= url, headers=headers)

# %%
print(response)
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><?xml-stylesheet type='text/xsl' href='/3.2/style/rplus.xsl' ?>
# <ops:world-patent-data xmlns:ops="http://ops.epo.org" xmlns:reg="http://www.epo.org/register" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns:cpc="http://www.epo.org/cpcexport" xmlns:cpcdef="http://www.epo.org/cpcdefinition">
#     <ops:register-search total-result-count="1053">
#         <ops:query syntax="CQL">ti=ai</ops:query>
#         <ops:range begin="1" end="25"/>
#         <reg:register-documents produced-by="RO">
#             <reg:register-document produced-by="RO">
#                 <reg:ep-patent-statuses>
#                     <reg:ep-patent-status change-date="" status-code=""/>
#                 </reg:ep-patent-statuses>
#                 <reg:bibliographic-data>
#                     <reg:publication-reference>
#                         <reg:document-id>
#                             <reg:country>WO</reg:country>
# ...
