# %% [markdown]
# <a href="https://colab.research.google.com/github/KarelCouceiro/Data_Monitor/blob/main/Code_llama_7B_Instruct_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install git+https://github.com/huggingface/transformers.git@main accelerate
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git (to revision main) to /tmp/pip-req-build-j9kpg920
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-j9kpg920
#   Resolved https://github.com/huggingface/transformers.git to commit 9e87618f2be1401df55c36ad726629ae201e8e4d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.0/261.0 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 33.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 80.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 79.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.8 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer
import transformers
import torch

# %%
model = "codellama/CodeLlama-7b-Instruct-hf"

# %%
tokenizer = AutoTokenizer.from_pretrained(model)
pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...

# %%
system = "You are a python Expert.Provide answers in python"
#user_input ="write a python code that creates text to speech"

user_input1 = """def add_even_numbers(a, b):
    #if a % 2 == 0 and b % 2 == 0:"""

prompt = f"<s><<SYS>>\n{system}\n<</SYS>>\n\n{user_input1}"

# %%
sequences = pipeline(
    prompt,
    do_sample=True,
    top_k=10,
    temperature=0.1,
    top_p=0.95,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
    max_length=200,
    add_special_tokens=False
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.

# %%
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Result: <s><<SYS>>
# You are a python Expert.Provide answers in python
# <</SYS>>
#
# def add_even_numbers(a, b):
#     #if a % 2 == 0 and b % 2 == 0:
#     #    return a + b
#     #else:
#     #    return "Only even numbers are allowed"
#     if a % 2 == 0 and b % 2 == 0:
#         return a + b
#     else:
#         return "Only even numbers are allowed"
#
#
# def add_even_numbers(a, b):
#     if a % 2 == 0 and b % 2 == 0:
#         return a + b
#     else:
#         return "Only even numbers are allowed"
#
#
# def add_even_numbers(a, b):
#     if a % 2 == 0 and
